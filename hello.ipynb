# %% [markdown]
# <a href="https://colab.research.google.com/github/Kas-sim/my_python/blob/collab/hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from transformers import pipeline
