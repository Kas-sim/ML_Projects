# %%
import torch
import transformers
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 import torch
#       2 import transformers
# ----> 3 from transformers import pipeline
#
# ImportError: cannot import name 'pipeline' from 'transformers' (d:\Programming\my_python\.venv\Lib\site-packages\transformers\__init__.py)

# %%
import torch

# 1. Check if PyTorch sees your RTX 4050
print(f"PyTorch Version: {torch.__version__}")
print(f"Is GPU available? {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
else:
    print("WARNING: You are running on CPU. Training will be slow.")

# 2. Quick test of DistilBERT (Downloads automatically)
print("\nDownloading a mini DistilBERT model to test connection...")
classifier = pipeline('sentiment-analysis', model='distilbert-base-uncased-finetuned-sst-2-english')
result = classifier("I am confused but I am learning fast!")

print(f"\nTest Result: {result}")
# Out:
# PyTorch Version: 2.9.1+cpu
# Is GPU available? False
# WARNING: You are running on CPU. Training will be slow.
#
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 14
#      12 # 2. Quick test of DistilBERT (Downloads automatically)
#      13 print("\nDownloading a mini DistilBERT model to test connection...")
# ---> 14 classifier = pipeline('sentiment-analysis', model='distilbert-base-uncased-finetuned-sst-2-english')
#      15 result = classifier("I am confused but I am learning fast!")
#      17 print(f"\nTest Result: {result}")
#
# NameError: name 'pipeline' is not defined

# %%
classifier = pipeline(
    task="text-classification",
    model="distilbert-base-uncased-finetuned-sst-2-english",
    dtype=torch.float16,
    device=0
)
result = classifier("I love using Hugging face ;)")
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 classifier = pipeline(
#       2     task="text-classification",
#       3     model="distilbert-base-uncased-finetuned-sst-2-english",
#       4     dtype=torch.float16,
#       5     device=0
#       6 )
#       7 result = classifier("I love using Hugging face ;)")
#       8 print(result)
#
# NameError: name 'pipeline' is not defined
